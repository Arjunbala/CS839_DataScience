# %% [markdown]
# # Prep 1: steps to install the packages

# %%
# !pip install py_entitymatching
# !pip install scipy
# !pip install numpy
# !pip install pandas
# Out:
# Collecting py_entitymatching
#   Downloading https://files.pythonhosted.org/packages/ee/d3/2eacdb4ee0e268eb4c041fc2921e880262658b24e15ae470559fb1999eab/py_entitymatching-0.3.1.tar.gz (2.0MB)
#     100% |████████████████████████████████| 2.0MB 1.9MB/s ta 0:00:01
# Collecting PyPrind (from py_entitymatching)
#   Downloading https://files.pythonhosted.org/packages/1e/30/e76fb0c45da8aef49ea8d2a90d4e7a6877b45894c25f12fb961f009a891e/PyPrind-2.11.2-py3-none-any.whl
# Collecting py_stringsimjoin==0.3.0 (from py_entitymatching)
#   Downloading https://files.pythonhosted.org/packages/b9/32/28a76b430e092a330850707e34f89419ce77b06dc303e6c5f6cd701ad5ba/py_stringsimjoin-0.3.0.tar.gz (786kB)
#     100% |████████████████████████████████| 788kB 1.7MB/s ta 0:00:01
# Requirement already satisfied: cloudpickle>=0.2.1 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from py_entitymatching) (0.5.3)
# Requirement already satisfied: pyparsing>=2.1.4 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from py_entitymatching) (2.2.0)
# Requirement already satisfied: scikit-learn>=0.18 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from py_entitymatching) (0.19.1)
# Collecting pandas-profiling>=1.4.0 (from py_entitymatching)
#   Downloading https://files.pythonhosted.org/packages/3b/98/e4cae9f4485be5ff589227af4e97dd7ebe60c1372bf6f8d9ccbeb0f90667/pandas-profiling-1.4.2.tar.gz
# Collecting joblib (from py_stringsimjoin==0.3.0->py_entitymatching)
#   Downloading https://files.pythonhosted.org/packages/cd/c1/50a758e8247561e58cb87305b1e90b171b8c767b15b12a1734001f41d356/joblib-0.13.2-py2.py3-none-any.whl (278kB)
#     100% |████████████████████████████████| 286kB 2.3MB/s ta 0:00:01
# Requirement already satisfied: pandas>=0.16.0 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from py_stringsimjoin==0.3.0->py_entitymatching) (0.23.0)
# Collecting py_stringmatching>=0.2.1 (from py_stringsimjoin==0.3.0->py_entitymatching)
#   Downloading https://files.pythonhosted.org/packages/3e/a3/89c3d02bbf1e24868673702ebd38a3b76259cb124a5d26d46a050d3fccf2/py_stringmatching-0.4.1.tar.gz (646kB)
#     100% |████████████████████████████████| 655kB 2.2MB/s ta 0:00:01
# Requirement already satisfied: six in /home/aditaker/anaconda3/lib/python3.6/site-packages (from py_stringsimjoin==0.3.0->py_entitymatching) (1.11.0)
# Requirement already satisfied: matplotlib>=1.4 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from pandas-profiling>=1.4.0->py_entitymatching) (2.2.2)
# Requirement already satisfied: jinja2>=2.8 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from pandas-profiling>=1.4.0->py_entitymatching) (2.10)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from pandas>=0.16.0->py_stringsimjoin==0.3.0->py_entitymatching) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /home/aditaker/anaconda3/lib/python3.6/site-packages (from pandas>=0.16.0->py_stringsimjoin==0.3.0->py_entitymatching) (2018.4)
# Requirement already satisfied: numpy>=1.9.0 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from pandas>=0.16.0->py_stringsimjoin==0.3.0->py_entitymatching) (1.14.3)
# Requirement already satisfied: cycler>=0.10 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from jinja2>=2.8->pandas-profiling>=1.4.0->py_entitymatching) (1.0)
# Requirement already satisfied: setuptools in /home/aditaker/anaconda3/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (39.1.0)
# Building wheels for collected packages: py-entitymatching, py-stringsimjoin, pandas-profiling, py-stringmatching
#   Building wheel for py-entitymatching (setup.py) ... done
#   Stored in directory: /home/aditaker/.cache/pip/wheels/8a/11/32/31986854281ff89654b9e67c1cb5d94dd8f87d7408aaef3c91
#   Building wheel for py-stringsimjoin (setup.py) ... done
#   Stored in directory: /home/aditaker/.cache/pip/wheels/69/a2/f7/b748da307ea9120633a58847b0ecec23c97cfccdf81d875282
#   Building wheel for pandas-profiling (setup.py) ... done
#   Stored in directory: /home/aditaker/.cache/pip/wheels/bf/c5/d0/7278ea92cf6195c9bef7d9b1b63767fc16dc490a2402287067
#   Building wheel for py-stringmatching (setup.py) ... done
#   Stored in directory: /home/aditaker/.cache/pip/wheels/60/7a/90/37ae79d15afb482c2fa1a58a45fadd1945ed1d09fc8d50d4b6
# Successfully built py-entitymatching py-stringsimjoin pandas-profiling py-stringmatching
# Installing collected packages: PyPrind, joblib, py-stringmatching, py-stringsimjoin, pandas-profiling, py-entitymatching
# Successfully installed PyPrind-2.11.2 joblib-0.13.2 pandas-profiling-1.4.2 py-entitymatching-0.3.1 py-stringmatching-0.4.1 py-stringsimjoin-0.3.0
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: scipy in /home/aditaker/anaconda3/lib/python3.6/site-packages (1.1.0)
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: numpy in /home/aditaker/anaconda3/lib/python3.6/site-packages (1.14.3)
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /home/aditaker/anaconda3/lib/python3.6/site-packages (0.23.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from pandas) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /home/aditaker/anaconda3/lib/python3.6/site-packages (from pandas) (2018.4)
# Requirement already satisfied: numpy>=1.9.0 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from pandas) (1.14.3)
# Requirement already satisfied: six>=1.5 in /home/aditaker/anaconda3/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas) (1.11.0)
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # [NEED MODIFICATION: Modify this cell to point to the file location]
# # Prep 2: enter the file location on your harddisk

# %%
table_a = 'IMDB'
table_b = 'Metacritic'
candidate_set = 'candidate_set_after_blocking_2'
prediction_set = 'MoviesMatching_cm_matching_al_ds'

# %% [markdown]
# # Prep 3: reading the files into pandas dataframe

# %%
import pandas as pd
dfa = pd.read_csv(table_a)
dfb = pd.read_csv(table_b)
dfc = pd.read_csv(candidate_set)
dfp = pd.read_csv(prediction_set)

# %% [markdown]
# # Module: debug_blocker
# # Description: debug the blocking rule using the below script to ensure you are not dropping true matches
# # Note: You need to run Prep 1 and 2 in order to run this

# %%
# Example input format:
# Format of table_a:
# _id, attribute1, attribute2, ....., attributen

# Format of table_b:
# _id, attribute1, attribute2, ....., attributen

# Format of candidate_set
# A_id,B_id
# where A_id is _id from table_a and B_id is the _id column value from table_b

# %%
import py_entitymatching as em
import pandas as pd

def run_debug_blocker(table_a, table_b, table_a_key, table_b_key, candidate_set):
    dfl = em.read_csv_metadata(table_a, key=table_a_key)
    dfr = em.read_csv_metadata(table_b, key=table_b_key)

    # reading the candidate set and adding key
    dfcand = pd.read_csv(candidate_set)
    dfcand.drop_duplicates(inplace=True)
    dfcand.to_csv('cand_set_with_index.csv', index_label='id')

    dfcset = em.read_csv_metadata('cand_set_with_index.csv', key='id', ltable=dfl, 
                                  rtable=dfr, fk_ltable='A_id', fk_rtable='B_id')

    # running debug blocker to identify the records in A x B \ C
    debug_file = em.debug_blocker(dfcset, dfl, dfr)
    
    return debug_file

# %%
debug_file = run_debug_blocker(table_a, table_b, '_id', '_id', candidate_set)
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
debug_file
# Out:
#      _id  ltable__id  rtable__id  \
# 0      0        2925        2432
# 1      1          42         234
# 2      2         259         473
# 3      3          87        2897
# 4      4        1297         242
# 5      5        1880        1968
# 6      6        2335        2272
# 7      7         455         637
# 8      8         605         541
# 9      9        2457        1072
# 10    10        1280        2906
# 11    11        2584         531
# 12    12        1723        1897
# 13    13        2140        2044
# 14    14        2955         439
# 15    15        2641        2490
# 16    16         873        2185
# 17    17        2209         518
# 18    18          78         544
# 19    19         115        2077
# 20    20          91         197
# 21    21         834        1137
# 22    22        1946         174
# 23    23         648        1869
# 24    24         699         377
# 25    25         527         453
# 26    26        1252        1549
# 27    27         608        1549
# 28    28         828        2060
# 29    29          42        2202
# ..   ...         ...         ...
# 170  170           6          71
# 171  171           8         109
# 172  172         443        1402
jet Li, Tony Chiu-Wai Leung, Maggie Cheung, Ziyi Zhang
# 194          Chris Sanders, Daveigh Chase, Chris Sanders, Tia Carrere, David Ogden Stiers
# 195                          Martin Sheen, Marlon Brando, Robert Duvall, Frederic Forrest
# 196                                   Min-sik Choi, Ji-tae Yu, Hye-jeong Kang, Dae-han Ji
# 197                               Bridgit Mendler, Amy Poehler, Will Arnett, Moises Arias
# 198                                      Jack Black, Mike White, Joan Cusack, Adam Pascal
# 199                     Daniel Auteuil, Juliette Binoche, Maurice Bnichou, Annie Girardot
#
#                      ltable_Genre ltable_Up_System  \
# 0           Crime, Drama, Romance               CM
# 1                    Crime, Drama               CM
# 2               Action, Adventure               CM
# 3       Adventure, Drama, Fantasy               CM
# 4             Drama, History, War               CM
# 5                           Drama               CM
# 6          Crime, Drama, Thriller               CM
# 7        Action, Sci-Fi, Thriller               CM
# 8                  Drama, Romance               CM
# 9          Action, Comedy, Sci-Fi               CM
# 10         Comedy, Drama, Romance               CM
# 11         Crime, Drama, Thriller               CM
# 12        Biography, Drama, Sport               CM
# 13        Action, Comedy, Fantasy               CM
# 14      Biography, Drama, History               CM
# 15         Comedy, Drama, Romance               CM
# 16                        Western               CM
# 17         Crime, Drama, Thriller               CM
# 18     Action, Adventure, Fantasy               CM
# 19      Action, Adventure, Sci-Fi               CM
# 20     Action, Adventure, Fantasy               CM
# 21        Biography, Crime, Drama               CM
# 22         Comedy, Drama, Romance               CM
# 23                Drama, Thriller               CM
# 24       Drama, History, Thriller               CM
# 25   Animation, Adventure, Family               CM
# 26         Comedy, Drama, Romance               CM
# 27                Comedy, Romance               CM
# 28                 Drama, Romance               CM
# 29                   Crime, Drama               CM
# ..                            ...              ...
# 170     Adventure, Drama, Fantasy               CM
# 171     Adventure, Drama, Fantasy               CM
# 172       Action, Fantasy, Horror               CM
# 173    Adventure, Family, Fantasy               CM
# 174  Animation, Adventure, Comedy               CM
# 175     Action, Adventure, Family               CM
# 176     Adventure, Comedy, Sci-Fi               CM
# 177     Action, Mystery, Thriller               CM
# 178     Action, Adventure, Comedy               CM
# 179     Action, Adventure, Sci-Fi               CM
# 180       Biography, Crime, Drama               CM
# 181        Comedy, Drama, Romance               CM
# 182               Comedy, Mystery               CM
# 183     Action, Adventure, Sci-Fi               CM
# 184                 Comedy, Crime               CM
# 185  Animation, Adventure, Comedy               CM
# 186     Action, Mystery, Thriller               CM
# 187    Action, Adventure, Fantasy               CM
# 188  Animation, Adventure, Comedy               CM
# 189                Drama, Romance               CM
# 190                Drama, Romance               CM
# 191                Drama, Romance               CM
# 192     Action, Adventure, Sci-Fi               CM
# 193    Action, Adventure, History               CM
# 194  Animation, Adventure, Comedy               CM
# 195                    Drama, War               CM
# 196        Action, Drama, Mystery               CM
# 197  Animation, Adventure, Family               CM
# 198                 Comedy, Music               CM
# 199      Drama, Mystery, Thriller               CM
#
#                                                         rtable_Name  \
# 0                                                              Time
# 1                                                       Raging Bull
# 2                                           Raiders of the Lost Ark
# 3                         Harry Potter and the Order of the Phoenix
# 4                                             Letters from Iwo Jima
# 5                                           The Flower of My Secret
# 6                                                            Oldboy
# 7                                                    The Terminator
# 8                                                         Atonement
# 9                                                          Superman
# 10                                                      Chasing Amy
# 11                                                 The Conversation
# 12                                         The Manchurian Candidate
# 13                                                              Spy
# 14                                                          Traffic
# 15                                                 Meet the Parents
# 16                                           For a Few Dollars More
# 17                                                       Unforgiven
# 18                          Star Wars: Episode VIII - The Last Jedi
jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Philip Seymour Hoffman
# 184                                                      Leslie Nielsen, O.J. Simpson, Priscilla Presley
# 185                                                               Cameron Diaz, Eddie Murphy, Mike Myers
# 186                                                                  dgar Ramrez, Joan Allen, Matt Damon
# 187                                                                 Doug Jones, Ron Perlman, Selma Blair
# 188                                                                                 Tim Allen, Tom Hanks
# 189                                                                             Ethan Hawke, Julie Delpy
# 190                                                                             Ethan Hawke, Julie Delpy
# 191                                                                             Ethan Hawke, Julie Delpy
# 192                                                               Chris Pine, Simon Pegg, Zachary Quinto
# 193                     Daoming Chen, Donnie Yen, Jet Li, Maggie Cheung, Tony Leung Chiu Wai, Ziyi Zhang
# 194                                                                         Chris Sanders, Daveigh Chase
# 195                                                                          Marlon Brando, Martin Sheen
# 196                                                              Hye-jeong Kang, Ji-tae Yu, Min-sik Choi
# 197                                                            Amy Poehler, Bridgit Mendler, Will Arnett
# 198                                                                  Jack Black, Joan Cusack, Mike White
# 199                                                                     Daniel Auteuil, Juliette Binoche
#
#                                       rtable_Genre rtable_Up_System
# 0                                   Drama, Romance               CM
# 1                          Biography, Drama, Sport               CM
# 2                                Action, Adventure               CM
# 3              Adventure, Mystery, Fantasy, Family               CM
# 4                              Drama, History, War               CM
# 5                                            Drama               CM
# 6                 Action, Drama, Mystery, Thriller               CM
# 7                         Action, Sci-Fi, Thriller               CM
# 8                     Drama, Mystery, Romance, War               CM
# 9              Action, Adventure, Sci-Fi, Thriller               CM
# 10                          Drama, Comedy, Romance               CM
# 11                        Drama, Mystery, Thriller               CM
# 12                        Drama, Mystery, Thriller               CM
# 13                           Action, Comedy, Crime               CM
# 14                          Drama, Thriller, Crime               CM
# 15                                 Comedy, Romance               CM
# 16                                         Western               CM
# 17                           Drama, Crime, Western               CM
# 18              Action, Adventure, Sci-Fi, Fantasy               CM
# 19             Action, Adventure, Sci-Fi, Thriller               CM
# 20              Action, Adventure, Sci-Fi, Fantasy               CM
# 21                            Drama, Comedy, Crime               CM
# 22                 Drama, Fantasy, Comedy, Romance               CM
# 23                                 Drama, Thriller               CM
# 24                  Biography, Drama, History, War               CM
# 25           Adventure, Fantasy, Animation, Family               CM
# 26                                  Sci-Fi, Comedy               CM
# 27                                  Sci-Fi, Comedy               CM
# 28                                  Drama, Romance               CM
# 29                                           Drama               CM
# ..                                             ...              ...
# 170                     Action, Adventure, Fantasy               CM
# 171                     Action, Adventure, Fantasy               CM
# 172                     Action, Adventure, Fantasy               CM
# 173                    Adventure, Mystery, Fantasy               CM
# 174  Adventure, Fantasy, Comedy, Animation, Family               CM
# 175                     Adventure, Fantasy, Family               CM
# 176                      Adventure, Sci-Fi, Comedy               CM
# 177           Action, Adventure, Mystery, Thriller               CM
# 178      Action, Adventure, Sci-Fi, Comedy, Family               CM
# 179                     Action, Adventure, Fantasy               CM
# 180                        Biography, Drama, Crime               CM
# 181                         Drama, Comedy, Romance               CM
# 182                                  Comedy, Crime               CM
# 183     Action, Adventure, Sci-Fi, Drama, Thriller               CM
# 184                 Action, Comedy, Romance, Crime               CM
# 185  Adventure, Fantasy, Comedy, Animation, Family               CM
# 186           Action, Adventure, Mystery, Thriller               CM
# 187     Action, Adventure, Sci-Fi, Fantasy, Horror               CM
# 188  Adventure, Fantasy, Comedy, Animation, Family               CM
# 189                                 Drama, Romance               CM
# 190                                 Drama, Romance               CM
# 191                                 Drama, Romance               CM
# 192                      Action, Adventure, Sci-Fi               CM
# 193                     Action, Adventure, History               CM
# 194           Adventure, Sci-Fi, Animation, Family               CM
# 195                             Action, Drama, War               CM
# 196               Action, Drama, Mystery, Thriller               CM
# 197          Adventure, Fantasy, Animation, Family               CM
# 198                          Comedy, Music, Family               CM
# 199                       Drama, Mystery, Thriller               CM
#
# [200 rows x 17 columns]

# %% [markdown]
# # Module: estimate_precision_recall
# # Description: the below code helps you get an estimation of P/R on the candidate set.

# %%
import pandas as pd
from scipy.stats import norm
from numpy import sqrt

delta = .05
Z = norm.ppf(1 - (delta / 2))

def estimate_PR(labeled_pairs, reduced_cands, predicted_matches):
    '''
    labeled_pairs - a pandas dataframe with schema id1,id2,label
                    Note label needs to be Boolean

    reduced_cands - a pandas dataframe with schema id1,id2
    predicted_matches - a pandas dataframe with schema id1,id2
    
    return:
        ( (recall lower bound, recall upper bound), (precision lower bound, precision upper bound) )
    '''

    labeled_pairs.drop_duplicates(inplace=True)
    labeled_pairs.columns = ['id1', 'id2', 'label']
    reduced_cands.columns = ['id1', 'id2']
    reduced_cand_set = set(zip(reduced_cands.id1, reduced_cands.id2))
    predicted_matches = set(zip(predicted_matches.id1, predicted_matches.id2))
    
    # estimate the recall
    # number of positives in the labeled sample
    actual_pos = float(labeled_pairs.label.sum())
    # the maximum number of postives in the candidate set
    max_actual_pos = float(actual_pos + len(reduced_cand_set) - len(labeled_pairs))
    
    # true positives in the labeled sample
    true_pos = float(labeled_pairs.apply(lambda x : (x['id1'], x['id2']) in predicted_matches and x['label'], axis=1).sum())
    #estimated recall
    recall = float(true_pos / actual_pos)

    recall_error = Z * sqrt( ((recall * (1 - recall)) / (actual_pos)) * ((max_actual_pos - actual_pos) / (max_actual_pos - 1)) )


    # estimate Precision
    labeled_set  = set(zip(labeled_pairs.id1, labeled_pairs.id2))
    predicted_pos = float(len(labeled_set & predicted_matches))
    
    predicted_pos_in_reduced_cand_set = float(len(reduced_cand_set & predicted_matches))
    
    alpha =  predicted_pos_in_reduced_cand_set / len(predicted_matches)
    precision = alpha * (true_pos / predicted_pos)
    
    precision_error = alpha * Z * sqrt( ((precision * (1 - precision)) / predicted_pos) * (float((len(predicted_matches) - predicted_pos)) / (len(predicted_matches)  - 1)) )

    return ((recall - recall_error, recall + recall_error),
            (precision - precision_error, precision + precision_error))

# %% [markdown]
# # [NEED MODIFICATION: Modify this cell to point to the file location]

# %%
# read the labeled pairs file, i.e. the file with the labels
labeled_pairs = pd.read_csv('Labeled_final')
print(estimate_PR(labeled_pairs, dfc, dfp))
# Out:
# ((1.0, 1.0), (0.9597402500318443, 0.9986098101849362))

# %% [markdown]
# # Alternatively if you run into issues running this script on your laptop you can use
# # https://colab.research.google.com/notebooks/welcome.ipynb
